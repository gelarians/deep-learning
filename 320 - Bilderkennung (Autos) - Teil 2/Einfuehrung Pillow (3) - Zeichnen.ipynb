# %%
from PIL import Image

img = Image.open("bild1.jpg")
img = img.resize((round(img.size[0] / 10), round(img.size[1] / 10)))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x10985C7F0>

# %%
from PIL import ImageDraw

draw = ImageDraw.Draw(img)

points = [
    (0, 0),
    (100, 100)
]
draw.line(points, "red", 5)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x10985C7F0>

# %%
points = [
    (100, 100),
    (100, 200)
]
draw.line(points, "green", 5)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x10985C7F0>

# %%
draw.rectangle([
    (50, 50),
    (150, 150)
], outline="yellow")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x10985C7F0>

# %%
draw.line([
    (50, 50),
    (150, 50),
    (150, 150),
    (50, 150),
    (50, 50)
], "blue", 10)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x10985C7F0>
