# %%
from PIL import Image

img = Image.open("bild1.jpg")
img = img.resize((round(img.size[0] / 10), round(img.size[1] / 10)))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x111FEC0B8>

# %%
img.crop((50, 50, 150, 150))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1132469B0>

# %%
import numpy as np

i = np.asarray(img.crop((50, 50, 150, 150)))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.imshow(i)
plt.show()

# %%
i.astype(np.float32) / 255.
# Out:
# array([[[0.38039216, 0.3254902 , 0.22352941],
#         [0.34117648, 0.30588236, 0.23921569],
#         [0.26666668, 0.23529412, 0.15294118],
#         ...,
#         [0.24705882, 0.2       , 0.14509805],
#         [0.23529412, 0.1882353 , 0.1254902 ],
#         [0.28627452, 0.23921569, 0.15294118]],
#
#        [[0.23529412, 0.20392157, 0.16078432],
#         [0.30588236, 0.27058825, 0.21176471],
#         [0.3254902 , 0.28627452, 0.23921569],
#         ...,
#         [0.16470589, 0.10980392, 0.06666667],
#         [0.16862746, 0.11764706, 0.08235294],
#         [0.15294118, 0.09411765, 0.06666667]],
#
#        [[0.21176471, 0.19607843, 0.16078432],
#         [0.21960784, 0.20392157, 0.16862746],
#         [0.23137255, 0.19607843, 0.16078432],
#         ...,
#         [0.16862746, 0.10196079, 0.07450981],
#         [0.14901961, 0.09019608, 0.0627451 ],
#         [0.17254902, 0.10196079, 0.08627451]],
#
#        ...,
#
#        [[0.8117647 , 0.61960787, 0.36078432],
#         [0.827451  , 0.627451  , 0.38039216],
#         [0.8392157 , 0.6117647 , 0.36078432],
#         ...,
#         [0.9137255 , 0.7882353 , 0.627451  ],
#         [0.9411765 , 0.8156863 , 0.6666667 ],
#         [0.85490197, 0.7490196 , 0.6313726 ]],
#
#        [[0.8352941 , 0.6392157 , 0.39215687],
#         [0.7882353 , 0.5882353 , 0.3647059 ],
#         [0.8509804 , 0.62352943, 0.37254903],
#         ...,
#         [0.9098039 , 0.79607844, 0.6313726 ],
#         [0.88235295, 0.7490196 , 0.6039216 ],
#         [0.9137255 , 0.8156863 , 0.69411767]],
#
#        [[0.83137256, 0.6313726 , 0.38431373],
#         [0.7490196 , 0.5529412 , 0.32156864],
#         [0.8392157 , 0.62352943, 0.36862746],
#         ...,
#         [0.8980392 , 0.78431374, 0.61960787],
#         [0.9098039 , 0.8       , 0.64705884],
#         [0.84705883, 0.7490196 , 0.627451  ]]], dtype=float32)
